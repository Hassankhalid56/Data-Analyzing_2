# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Customer Call List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=load.drop_duplicates()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=load.drop_duplicates()
#       2 df
#
# NameError: name 'load' is not defined

# %%
df.drop(columns="Not_Useful_Column")

# %%
df['Last_Name']=df['Last_Name'].str.strip("123._/") #remove useless things
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number']= df['Phone_Number'].str.strip("123-/|")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643/9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter           NaN
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('|','-' , regex = False)
df["Phone_Number"] = df["Phone_Number"].str.replace('/','-' , regex = False)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           N-a
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter           NaN
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].replace([np.nan, 'NA','NaN'],'') #Remove through Numpy nan with this syntax
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           N-a
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace('Yes', 'Y')
df["Paying Customer"] = df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           N-a
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Nan','' , regex = False)
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Nan','' , regex = False)
df["Do_Not_Contact"] = df["Do_Not_Contact"].fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           N-a
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# ...

# %%
df["Address"] = df["Address"].str.replace('N/a','' , regex = False)
df["Paying Customer"] = df["Paying Customer"].str.replace('N/a','' , regex = False)
df["Address"] = df["Address"].fillna('')
df["Paying Customer"] = df["Paying Customer"].fillna('')
df["Phone_Number"] = df["Phone_Number"].str.replace('N-a','' , regex = False)
df["Phone_Number"] = df["Phone_Number"].fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Address"] = df["Address"].astype(str)
# Split the 'Address' column by the first comma and expand into two columns
split_columns = df["Address"].str.split(',', n=1, expand=True)
# Assign new columns to the DataFrame
df[['Streets', 'Post code']] = split_columns
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df.drop(columns = 'Address')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins        545-54               Y
# 1         1002       Abed       Nadir      643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute      543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson   04-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf         NaN                             Y
# 9         1010      Peter      Parker        545-54               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper      543-2345               Y
# ...

# %%
df['Post code'] = df['Post code'].str.replace('Pennsylvania, 18503', 'None', )
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins        545-54
# 1         1002       Abed       Nadir      643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute      543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson   04-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker        545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper      543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson   04-762-2467
# 15        1016        Ron     Weasley        545-54
# 16        1017   Michael        Scott      643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...
